# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/자기주도연구
# Out:
# /content/drive/MyDrive/자기주도연구

# %%
# !ls
# Out:
# '2차전처리 후 남은 데이터.ipynb'	  comments_중증외상센터_keyword.csv  '데이터 수집'
# 'comments_나의 완벽한 비서_keyword.csv'   filtering.ipynb		     '데이터 통계.ipynb'
#  comments_모텔캘리포니아_keyword.csv	 '관련없는 댓글 삭제(전처리)'	     '세부적 이유 추출'
#  comments_오징어게임2_keyword.csv	 '긍정부정 이유(keyword).ipynb'      '언급횟수 그래프'
#  comments_옥씨부인전_keyword.csv	 '댓글데이터 수집.ipynb'
#  comments_원경_keyword.csv		 '댓글 정리.ipynb'

# %%
import pandas as pd

# %%
com1 = pd.read_csv('comments_나의 완벽한 비서_keyword.csv')
com2 = pd.read_csv('comments_모텔캘리포니아_keyword.csv')
com3 = pd.read_csv('comments_오징어게임2_keyword.csv')
com4 = pd.read_csv('comments_원경_keyword.csv')
com5 = pd.read_csv('comments_옥씨부인전_keyword.csv')
com6 = pd.read_csv('comments_중증외상센터_keyword.csv')

# %%
len(com1)+len(com2)+len(com3)+len(com4)+len(com5)+len(com6)
# Out:
# 5459
